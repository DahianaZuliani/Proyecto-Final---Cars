# %%
pip list
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Package                           Version
# --------------------------------- --------------------
# aext-assistant                    4.20.0
# aext-assistant-server             4.20.0
# aext-core                         4.20.0
# aext-core-server                  4.20.0
# aext_environments_server          4.20.0
# aext-panels                       4.20.0
# aext-panels-server                4.20.0
# aext-project-filebrowser-server   4.20.0
# aext-share-notebook               4.20.0
# aext-share-notebook-server        4.20.0
# aext-shared                       4.20.0
# aext-toolbox                      4.20.0
# aiobotocore                       2.25.0
# aiodns                            3.5.0
# aiohappyeyeballs                  2.6.1
# aiohttp                           3.13.2
# aioitertools                      0.12.0
# aiosignal                         1.4.0
# alabaster                         0.7.16
# ...

# %% [markdown]
# # Proyecto Integrador –Evaluación Cars - Sección 1
# ## Calidad y Preparación de Datos
# ### Alumna: Dahiana Gisselle Zuliani Quijano

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_excel("car_evaluation.xlsx")
# Out:
#       vhigh vhigh.1      2   2.1  small   low  unacc
# 0     vhigh   vhigh      2     2  small   med  unacc
# 1     vhigh   vhigh      2     2  small  high  unacc
# 2     vhigh   vhigh      2     2    med   low  unacc
# 3     vhigh   vhigh      2     2    med   med  unacc
# 4     vhigh   vhigh      2     2    med  high  unacc
# ...     ...     ...    ...   ...    ...   ...    ...
# 1722    low     low  5more  more    med   med   good
# 1723    low     low  5more  more    med  high  vgood
# 1724    low     low  5more  more    big   low  unacc
# 1725    low     low  5more  more    big   med   good
# 1726    low     low  5more  more    big  high  vgood
#
# [1727 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   vhigh    1727 non-null   object
#  1   vhigh.1  1727 non-null   object
#  2   2        1727 non-null   object
#  3   2.1      1727 non-null   object
#  4   small    1727 non-null   object
#  5   low      1727 non-null   object
#  6   unacc    1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.describe(include='all')
# Out:
#        vhigh vhigh.1     2   2.1 small   low  unacc
# count   1727    1727  1727  1727  1727  1727   1727
# unique     4       4     4     3     3     3      4
# top     high    high     3     4   med   med  unacc
# freq     432     432   432   576   576   576   1209

# %%
df.isnull().sum()
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = ["buying", "maint", "doors", "persons", "lug_boot", "safety", "class"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df, x="safety")
plt.title("Distribución de niveles de seguridad")
plt.show()

# %%
sns.countplot(data=df, x="lug_boot", hue="class")
plt.title("Tamaño del maletero vs Clase del vehículo")
plt.show()

# %%
sns.countplot(data=df, x="doors", hue="class")
plt.title("Puertas vs Clase del vehículo")
plt.show()

# %% [markdown]
#  Conclusión de la Sección 1
# El dataset car_evaluation.xlsx contiene información categórica sobre características de vehículos y su clasificación final. Tras realizar el análisis exploratorio, se observó que los datos no presentan valores nulos ni duplicados, lo que indica una buena calidad inicial. Todas las variables son categóricas, por lo que no requieren transformaciones numéricas, aunque sí fue necesario renombrar las columnas para mejorar la claridad y consistencia del análisis.
# Las visualizaciones permitieron identificar patrones relevantes, como la relación entre el nivel de seguridad y la aceptabilidad del vehículo, así como la influencia del tamaño del maletero y el número de puertas en la clasificación final. Estos hallazgos facilitan la comprensión del comportamiento del dataset y preparan adecuadamente la información para su posterior análisis en Power BI.
# En resumen, la calidad del dataset es adecuada, las transformaciones aplicadas mejoran su interpretabilidad y el análisis exploratorio proporciona una base sólida para continuar con la Sección 2 del proyecto
